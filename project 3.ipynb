# %%
import matplotlib.pyplot as plt
blood_sugar_men=[113,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[110,123,88,90,100,120,98,150,115,80,117,92,129]

plt.ylabel('Total no. of patients')
plt.xlabel('Sugar range')
plt.title('Blood sugar analysis')

plt.hist([blood_sugar_men, blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=['red','black'],label=['men','women'])

plt.legend()
